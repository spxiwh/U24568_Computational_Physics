# %% [markdown]
# # Function as a value and the lambda operator - Overview
#
# In our last topic of this lecture, let's explore the idea of functions as a value themselves, and the lambda operator in python.
#
# Let's take a closer look at the `math.sin` function:

# %%
import math

a = math.sin
b = math.sin(3.0)

print(a, b)
# Out:
# <built-in function sin> 0.1411200080598672

# %% [markdown]
# The meaning of `b` is (I hope!) clear. It's a float storing the sin of 3.0 .... Or it's the result of *operating* the function `math.sin` on the float `3.0`. However, `a` is the function itself. So we can do:

# %%
a = math.sin
b = math.sin(3.0)
c = a(b)

print(a, b, c)
# Out:
# <built-in function sin> 0.1411200080598672 0.14065207678644337

# %% [markdown]
# This can be useful if want to write a function that will take as input a value (`x`), and a function (`F`), and returns `F(x)`:

# %%
def F_of_x(F, x):
    return F(x)

print(F_of_x(math.sin, 1.0), math.sin(1.0))
print(F_of_x(math.cos, 1.0), math.cos(1.0))
print(F_of_x(math.exp, 2.0), math.exp(2.0))
# Out:
# 0.8414709848078965 0.8414709848078965
# 0.5403023058681398 0.5403023058681398
# 7.38905609893065 7.38905609893065

# %% [markdown]
# One example of a function taking another (which we briefly touched on earlier in the course) is the sorted function. This takes a function which can determine a sort order. For example if I wanted to sort values between 0 and 10 according to the sin of that value I could do:

# %%
import numpy as np
inputs = np.linspace(0,10,100)
sorted_inps = sorted(inputs, key=math.sin)
print(sorted_inps)
# Checking that this worked as intended.
print ([math.sin(val) for val in sorted_inps])
# Out:
# [4.747474747474747, 4.646464646464646, 4.848484848484849, 4.545454545454545, 4.94949494949495, 4.444444444444445, 5.05050505050505, 4.343434343434343, 5.151515151515151, 4.242424242424242, 5.252525252525253, 4.141414141414141, 5.353535353535354, 4.040404040404041, 5.454545454545454, 3.9393939393939394, 5.555555555555555, 3.8383838383838382, 5.656565656565657, 3.7373737373737375, 10.0, 5.757575757575758, 3.6363636363636362, 9.8989898989899, 5.858585858585858, 3.5353535353535355, 9.797979797979798, 5.959595959595959, 3.4343434343434343, 9.696969696969697, 6.0606060606060606, 3.3333333333333335, 9.595959595959595, 6.161616161616162, 3.2323232323232323, 9.494949494949495, 6.262626262626262, 0.0, 3.131313131313131, 9.393939393939394, 6.363636363636363, 0.10101010101010101, 3.0303030303030303, 9.292929292929292, 6.4646464646464645, 0.20202020202020202, 2.929292929292929, 9.191919191919192, 6.565656565656566, 0.30303030303030304, 2.8282828282828283, 9.09090909090909, 6.666666666666667, 0.40404040404040403, 2.727272727272727, 8.98989898989899, 6.767676767676767, 0.5050505050505051, 2.6262626262626263, 8.88888888888889, 6.8686868686868685, 0.6060606060606061, 2.525252525252525, 8.787878787878787, 6.96969696969697, 0.7070707070707071, 2.4242424242424243, 8.686868686868687, 7.070707070707071, 0.8080808080808081, 2.323232323232323, 8.585858585858587, 7.171717171717171, 0.9090909090909091, 2.2222222222222223, 8.484848484848484, 7.2727272727272725, 1.0101010101010102, 2.121212121212121, 8.383838383838384, 7.373737373737374, 1.1111111111111112, 2.0202020202020203, 8.282828282828282, 7.474747474747475, 1.2121212121212122, 1.9191919191919191, 8.181818181818182, 7.575757575757575, 1.3131313131313131, 1.8181818181818181, 8.080808080808081, 7.6767676767676765, 1.4141414141414141, 1.7171717171717171, 7.979797979797979, 7.777777777777778, 1.5151515151515151, 1.6161616161616161, 7.878787878787879]
# [-0.9993845576124357, -0.9978277779792126, -0.9907532430056771, -0.9860987744909296, -0.9720218249588334, -0.9643171169287782, -0.9433812584459996, -0.9327048555318336, -0.9051235159501367, -0.8915842573351402, -0.8576386109880517, -0.8413745208608701, -0.8014106221689696, -0.7825875026542022, -0.7370127583189133, -0.7158224992291902, -0.6651015149788224, -0.6417601376193878, -0.5864099818472351, -0.5611554368152017, -0.5440211108893698, -0.5017403693939113, -0.47483011082223947, -0.45663748763377376, -0.4119558308308628, -0.38366419180611233, -0.3645987336558887, -0.31797166281061867, -0.28858705872043244, -0.26884312591038406, -0.22074597455506334, -0.19056796287548539, -0.1703468323280965, -0.12126992053716677, -0.09060614703340773, -0.07011396040064677, -0.020557596287260064, 0.0, 0.010279341240534697, 0.03083367906114098, 0.08036429967028173, 0.1008384202581046, 0.11106003812412972, 0.13146698864295842, 0.18046693235991093, 0.2006488565226854, 0.2107085480771929, 0.23076007532505177, 0.27872981867755725, 0.2984138044476411, 0.30820901749007684, 0.32770070881349983, 0.37415123057121996, 0.3931366121483298, 0.40256749066949654, 0.4213006405886069, 0.4657584070256517, 0.48385164043793466, 0.4928220425889235, 0.510605678474283, 0.5526174707464059, 0.5696341069089657, 0.5780525851065732, 0.5947054140244975, 0.6338429484489058, 0.6496095135057065, 0.6573902466827755, 0.6727425035622647, 0.7086067976992182, 0.7229625614794605, 0.7300262299764464, 0.7439214082568444, 0.7761468482835805, 0.7889454628442574, 0.7952200570230491, 0.8075165041395626, 0.8357745720522589, 0.8468855636029834, 0.8523071179396752, 0.8628794793817834, 0.8868821020290788, 0.8961922010299563, 0.9007054462029555, 0.9094459434244625, 0.9289484292312513, 0.9363627251042848, 0.9399216514301312, 0.9467411805833543, 0.9615447140268235, 0.9669876227092996, 0.9695559491823237, 0.9743849894755358, 0.9843386578838236, 0.9877546923600838, 0.9893062365143401, 0.9920955589323228, 0.9970978909438748, 0.9984522269003895, 0.9989711717233568, 0.9996923408861117]

# %% [markdown]
# The `lambda` function can be used to quickly define simple functions. For example if we wanted to define a function that returns $x^2$, we could do:

# %%
def x_squared(x):
    return x * x

# %% [markdown]
# Or this could be written as a single line function according to:

# %%
x_squared_alt = lambda x : x*x

print(x_squared(10), x_squared_alt(10))
# Out:
# 100 100

# %% [markdown]
# A standard usecase for this is being able to write `sorted` commands which do not extend over multiple lines, for example we could do:

# %%
import numpy as np
inputs = np.linspace(-9.5,10,51)
sorted_inps = sorted(inputs, key=lambda x : (x-2)*(x-2))
print(sorted_inps)
# Out:
# [1.8100000000000005, 2.200000000000001, 1.42, 2.59, 1.0300000000000011, 2.9800000000000004, 0.6400000000000006, 3.370000000000001, 0.25, 3.76, -0.14000000000000057, 4.15, -0.5299999999999994, 4.540000000000001, -0.9199999999999999, 4.93, -1.3100000000000005, 5.32, -1.6999999999999993, 5.710000000000001, -2.09, 6.100000000000001, -2.4799999999999995, 6.49, -2.87, 6.879999999999999, -3.26, 7.27, -3.6499999999999995, 7.66, -4.04, 8.05, -4.43, 8.440000000000001, -4.82, 8.830000000000002, -5.21, 9.219999999999999, -5.6, 9.61, -5.99, 10.0, -6.38, -6.77, -7.16, -7.55, -7.9399999999999995, -8.33, -8.72, -9.11, -9.5]
