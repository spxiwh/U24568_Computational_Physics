# %% [markdown]
# # Plotting
#
# Finally we remind how to make plots in python.

# %% [markdown]
# ## Making a Simple Plot

# %%
import matplotlib.pyplot as plt # Module for plotting
import numpy as np

# %%
xarr1 = np.linspace(-10, 10, 8)
yarr1 = xarr1**2

# %%
plt.plot(xarr1, yarr1)

# %%
plt.scatter(xarr1,yarr1)

# %% [markdown]
# Let's learn to fit a polynomial to the data.

# %%
a, b, c = np.polyfit(xarr1, yarr1, 2)
print(a,b,c)
# Out:
# 1.0000000000000004 -1.2969380457966237e-16 1.1992655761141625e-14

# %%
xarr = np.linspace(-10,10,1000)
plt.scatter(xarr1,yarr1)
plt.plot(xarr, a*xarr**2 + b*xarr + c)

# %% [markdown]
# **Exercise**: Instead of plotting `y=x**2` plot `y=x**5` and do a fit using polyfit, with a couple of different orders of polynomial.

# %%
xarr1 = np.linspace(-10, 10, 8)
yarr1 = xarr1**5

a, b, c, d, e, f = np.polyfit(xarr1, yarr1, 5)
print(a,b,c, d, e, f)

plt.scatter(xarr1,yarr1)
xarr2 = np.linspace(-10,10,1000)
plt.plot(xarr, a*xarr**5 + b*xarr**4 + c*xarr**3 + d*xarr**2 + e*xarr + f)
# Out:
# 0.9999999999999994 7.595125708114705e-15 3.8527458640938024e-15 2.6793129721567173e-13 3.5048173341916133e-12 2.199897371382206e-11

# %% [markdown]
# **Exercise**: Now do the same with `y=sin(x)`.

# %%
xarr1 = np.linspace(-10, 10, 200)
yarr1 = np.sin(xarr1)

a, b, c, d, e, f = np.polyfit(xarr1, yarr1, 5)
print(a,b,c, d, e, f)

plt.scatter(xarr1,yarr1)
xarr2 = np.linspace(-10,10,1000)
plt.plot(xarr, a*xarr**5 + b*xarr**4 + c*xarr**3 + d*xarr**2 + e*xarr + f)
# Out:
# -4.990475881559551e-05 0.0 0.006200360843906903 -4.586316290013725e-18 -0.13521248691565244 1.436091887786016e-16
